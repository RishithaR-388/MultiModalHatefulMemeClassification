# %%
# !git clone https://gitlab.com/bottle_shop/safe/prompthate.git
# Out:
# Cloning into 'prompthate'...
# remote: Enumerating objects: 95, done.
# remote: Total 95 (delta 0), reused 0 (delta 0), pack-reused 95
# Receiving objects: 100% (95/95), 3.74 MiB | 3.24 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# %cd /content/prompthate/PromptHate-Code/
# Out:
# /content/prompthate/PromptHate-Code

# %%
# !bash run.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: 1 Iteration: 389 1.2108449935913086 tensor(10., device='cuda:0')
# Epoch: 1 Iteration: 390 1.1171491146087646 tensor(11., device='cuda:0')
# Epoch: 1 Iteration: 391 0.9518523812294006 tensor(12., device='cuda:0')
# Epoch: 1 Iteration: 392 1.0577616691589355 tensor(12., device='cuda:0')
# Epoch: 1 Iteration: 393 0.8488967418670654 tensor(13., device='cuda:0')
# Epoch: 1 Iteration: 394 0.7587575912475586 tensor(14., device='cuda:0')
# Epoch: 1 Iteration: 395 1.1467067003250122 tensor(12., device='cuda:0')
# Epoch: 1 Iteration: 396 0.7419424653053284 tensor(15., device='cuda:0')
# Epoch: 1 Iteration: 397 1.0197747945785522 tensor(13., device='cuda:0')
# Epoch: 1 Iteration: 398 1.0659923553466797 tensor(11., device='cuda:0')
# Epoch: 1 Iteration: 399 1.4215972423553467 tensor(12., device='cuda:0')
# Epoch: 1 Iteration: 400 1.4896681308746338 tensor(11., device='cuda:0')
# ...
